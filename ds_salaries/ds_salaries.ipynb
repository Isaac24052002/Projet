# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ds_salaries.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'work_year',
#  'experience_level',
#  'employment_type',
#  'job_title',
#  'salary',
#  'salary_currency',
#  'salary_in_usd',
#  'employee_residence',
#  'remote_ratio',
#  'company_location',
#  'company_size']

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# ...

# %%
.df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df['job_title'].value_counts()
# Out:
# job_title
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Machine Learning Scientist                    8
# Big Data Engineer                             8
# Director of Data Science                      7
# AI Scientist                                  7
# Principal Data Scientist                      7
# Data Science Consultant                       7
# Data Analytics Manager                        7
# BI Data Analyst                               6
# Computer Vision Engineer                      6
# ML Engineer                                   6
# Lead Data Engineer                            6
# Applied Data Scientist                        5
# ...

# %%
.df['experience_level'].value_counts()
# Out:
# experience_level
# SE    280
# MI    213
# EN     88
# EX     26
# Name: count, dtype: int64

# %%
sns.countplot(x='experience_level', data=df);

# %%
sns.barplot(x='experience_level', y='salary_in_usd', data=df);

# %%
sns.barplot(x='company_size', y='salary_in_usd', data=df);

# %%
sns.barplot(x='work_year', y='salary_in_usd', data=df);

# %%
salaire_annee = df.groupby('work_year')['salary_in_usd'].mean()

# %%
salaire_annee.plot(kind='bar');

# %%
salaire_annee[2021] - salaire_annee[2020]
# Out:
# np.float64(4040.7926267281146)

# %%
salaire_annee[2022] - salaire_annee[2021]
# Out:
# np.float64(24668.213662580063)

# %%
df['salary_currency'].value_counts()
# Out:
# salary_currency
# USD    398
# EUR     95
# GBP     44
# INR     27
# CAD     18
# JPY      3
# PLN      3
# TRY      3
# HUF      2
# MXN      2
# CNY      2
# SGD      2
# DKK      2
# AUD      2
# BRL      2
# CLP      1
# CHF      1
# Name: count, dtype: int64

# %%
df['employment_type'].value_counts()
# Out:
# employment_type
# FT    588
# PT     10
# CT      5
# FL      4
# Name: count, dtype: int64

# %%
sns.barplot(x='employment_type', y='salary_in_usd', data=df);

# %%
resid = df.groupby('employee_residence')['job_title'].count().sort_values(ascending=False).head(10)

# %%
resid
# Out:
# employee_residence
# US    332
# GB     44
# IN     30
# CA     29
# DE     25
# FR     18
# ES     15
# GR     13
# JP      7
# PK      6
# Name: job_title, dtype: int64

# %%
resid.plot();

# %%
df.groupby('company_size').size().plot(
    kind='pie',
    autopct='%1.1f%%',
    title="Emplois par taille d'entreprise"
);

# %%
df.groupby('remote_ratio')['salary_in_usd'].mean().plot(
    kind='bar',
    title='Remote Ratio vs Salary'
);

# %%
df['job_title'].value_counts().head(10).plot(
    kind='bar',
    title='Top 10 des métiers les plus demandés'
);

# %%
df.groupby('work_year')['salary_in_usd'].mean().plot(
    kind='line', marker='o');
plt.xticks(rotation=45);

# %%
df.groupby('experience_level')['remote_ratio'].mean().plot(
    kind='bar',
    title='Experience Level vs Remote Ratio'
);
